# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
air=pd.read_csv("India Air Quality Data (1).csv",encoding='ISO-8859-1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23104\2454048557.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   air=pd.read_csv("India Air Quality Data (1).csv",encoding='ISO-8859-1')

# %%
air.head(10)
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5    152.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 6    150.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 7    151.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 8    152.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 9    151.0       May - M051990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# ...

# %%
air.shape
# Out:
# (435742, 13)

# %%
air.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
air.count()
# Out:
# stn_code                       291665
# sampling_date                  435739
# state                          435742
# location                       435739
# agency                         286261
# type                           430349
# so2                            401096
# no2                            419509
# rspm                           395520
# spm                            198355
# location_monitoring_station    408251
# pm2_5                            9314
# date                           435735
# dtype: int64

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
air.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
air.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
A=air.dropna()

# %%
A.shape
# Out:
# (0, 13)

# %%
A=air.fillna(0)

# %%
A.shape
# Out:
# (435742, 13)

# %%
A.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad      0
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad      0
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   0.0  0.0
# 1                     Industrial Area  3.1   7.0   0.0  0.0
# 2  Residential, Rural and other Areas  6.2  28.5   0.0  0.0
# 3  Residential, Rural and other Areas  6.3  14.7   0.0  0.0
# 4                     Industrial Area  4.7   7.5   0.0  0.0
#
#   location_monitoring_station  pm2_5        date
# 0                           0    0.0  1990-02-01
# 1                           0    0.0  1990-02-01
# 2                           0    0.0  1990-02-01
# ...

# %%
A = air['so2'].replace(np.NaN,air['so2'].mean())

# %%
A.head()
# Out:
# 0    4.8
# 1    3.1
# 2    6.2
# 3    6.3
# 4    4.7
# Name: so2, dtype: float64

# %%
A = air['so2'].replace(np.NaN,air['so2'].median())

# %%
A.head()
# Out:
# 0    4.8
# 1    3.1
# 2    6.2
# 3    6.3
# 4    4.7
# Name: so2, dtype: float64

# %%
A = pd.DataFrame(A, columns=air.columns)

# %%
A.head()
# Out:
#   stn_code sampling_date state location agency type  so2  no2 rspm  spm  \
# 0      NaN           NaN   NaN      NaN    NaN  NaN  4.8  NaN  NaN  NaN
# 1      NaN           NaN   NaN      NaN    NaN  NaN  3.1  NaN  NaN  NaN
# 2      NaN           NaN   NaN      NaN    NaN  NaN  6.2  NaN  NaN  NaN
# 3      NaN           NaN   NaN      NaN    NaN  NaN  6.3  NaN  NaN  NaN
# 4      NaN           NaN   NaN      NaN    NaN  NaN  4.7  NaN  NaN  NaN
#
#   location_monitoring_station pm2_5 date
# 0                         NaN   NaN  NaN
# 1                         NaN   NaN  NaN
# 2                         NaN   NaN  NaN
# 3                         NaN   NaN  NaN
# 4                         NaN   NaN  NaN

# %%
#integration

da1=air.loc[111:999,['state', 'location' ,'so2', 'rspm']]

# %%
da2=air.iloc[[1,3,5,2,4,22,43,54,67,7,8,9,50,10,11]]

# %%
da1
# Out:
#               state        location   so2  rspm
# 111  Andhra Pradesh       Hyderabad   4.9   NaN
# 112  Andhra Pradesh  Vishakhapatnam   NaN   NaN
# 113  Andhra Pradesh  Vishakhapatnam  11.2   NaN
# 114  Andhra Pradesh  Vishakhapatnam   4.5   NaN
# 115  Andhra Pradesh       Hyderabad   6.2   NaN
# ..              ...             ...   ...   ...
# 995  Andhra Pradesh       Hyderabad   2.8   NaN
# 996  Andhra Pradesh       Hyderabad   5.0   NaN
# 997  Andhra Pradesh       Hyderabad   5.5   NaN
# 998  Andhra Pradesh       Hyderabad   5.8   NaN
# 999  Andhra Pradesh       Hyderabad   5.9   NaN
#
# [889 rows x 4 columns]

# %%
da2
# Out:
#    stn_code        sampling_date           state   location  \
# 1     151.0   February - M021990  Andhra Pradesh  Hyderabad
# 3     150.0      March - M031990  Andhra Pradesh  Hyderabad
# 5     152.0      March - M031990  Andhra Pradesh  Hyderabad
# 2     152.0   February - M021990  Andhra Pradesh  Hyderabad
# 4     151.0      March - M031990  Andhra Pradesh  Hyderabad
# 22    152.0  September - M091990  Andhra Pradesh  Hyderabad
# 43    152.0        May - M051991  Andhra Pradesh  Hyderabad
# 54    151.0  September - M091991  Andhra Pradesh  Hyderabad
# 67    203.0    January - M011992  Andhra Pradesh  Hyderabad
# 7     151.0      April - M041990  Andhra Pradesh  Hyderabad
# 8     152.0      April - M041990  Andhra Pradesh  Hyderabad
# 9     151.0        May - M051990  Andhra Pradesh  Hyderabad
# 50    150.0     August - M081991  Andhra Pradesh  Hyderabad
# 10    152.0        May - M051990  Andhra Pradesh  Hyderabad
# 11    150.0       June - M061990  Andhra Pradesh  Hyderabad
#
# ...

# %%
air_integration=pd.concat([da1,da2])
air_integration
# Out:
#               state        location   so2  rspm stn_code     sampling_date  \
# 111  Andhra Pradesh       Hyderabad   4.9   NaN      NaN               NaN
# 112  Andhra Pradesh  Vishakhapatnam   NaN   NaN      NaN               NaN
# 113  Andhra Pradesh  Vishakhapatnam  11.2   NaN      NaN               NaN
# 114  Andhra Pradesh  Vishakhapatnam   4.5   NaN      NaN               NaN
# 115  Andhra Pradesh       Hyderabad   6.2   NaN      NaN               NaN
# ..              ...             ...   ...   ...      ...               ...
# 8    Andhra Pradesh       Hyderabad   4.2   NaN    152.0   April - M041990
# 9    Andhra Pradesh       Hyderabad   4.0   NaN    151.0     May - M051990
# 50   Andhra Pradesh       Hyderabad   8.5   NaN    150.0  August - M081991
# 10   Andhra Pradesh       Hyderabad   3.6   NaN    152.0     May - M051990
# 11   Andhra Pradesh       Hyderabad   3.9   NaN    150.0    June - M061990
#
#     agency                                type   no2    spm  \
# ...

# %%
air_integration.transpose()
# Out:
#                                         111             112             113  \
# state                        Andhra Pradesh  Andhra Pradesh  Andhra Pradesh
# location                          Hyderabad  Vishakhapatnam  Vishakhapatnam
# so2                                     4.9             NaN            11.2
# rspm                                    NaN             NaN             NaN
# stn_code                                NaN             NaN             NaN
# sampling_date                           NaN             NaN             NaN
# agency                                  NaN             NaN             NaN
# type                                    NaN             NaN             NaN
# no2                                     NaN             NaN             NaN
# spm                                     NaN             NaN             NaN
# location_monitoring_station             NaN             NaN             NaN
# ...

# %%
air.drop(columns='so2')
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
#transformation
from sklearn.preprocessing import LabelEncoder

# %%
col_label=air[['state','location','type']]

# %%
encoder=LabelEncoder()
for col in col_label:
    air[col] = encoder.fit_transform(air[col])

# %%
air
# Out:
#        stn_code       sampling_date  state  location  \
# 0         150.0  February - M021990      0       114
# 1         151.0  February - M021990      0       114
# 2         152.0  February - M021990      0       114
# 3         150.0     March - M031990      0       114
# 4         151.0     March - M031990      0       114
# ...         ...                 ...    ...       ...
# 435737     SAMP            24-12-15     35       282
# 435738     SAMP            29-12-15     35       282
# 435739      NaN                 NaN     36       304
# 435740      NaN                 NaN     17       304
# 435741      NaN                 NaN     31       304
#
#                                            agency  type   so2   no2   rspm  \
# 0                                             NaN     6   4.8  17.4    NaN
# 1                                             NaN     1   3.1   7.0    NaN
# 2                                             NaN     6   6.2  28.5    NaN
# ...

# %%
from sklearn import linear_model,metrics

# %%
x=df1[['age']]
y=df1[['thal']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x ,y, test_size=0.2,random_state=1)

# %%
from sklearn.model_selection import train_test_split

# %%
len(A)

# %%
train, test = train_test_split(A)

# %%
len(train)

# %%
len(test)

# %%
train.head(10)

# %%
train, test = train_test_split(A, test_size = 0.20)

# %%
len(test)

# %%
len(train)

# %%
A.describe()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
B = scaler.fit_transform(A)

# %%
pd.DataFrame(B).describe()

# %%
B = pd.DataFrame(B).describe()

# %%
#second method

from sklearn.preprocessing import Binarizer

# %%
bin = Binarizer(threshold=0.5)

# %%
B = bin.fit_transform(B)

# %%
pd.DataFrame(B)

# %%
from sklearn.linear_model import LinearRegression

# %%
X=A['so2'].values

# %%
X=X.reshape(-1,1)

# %%
Y = A['stn_code']

# %%
model = LinearRegression()

# %%
model.fit(X,Y)

# %%
model.score(X,Y)*100

# %%
model.predict([[128]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
